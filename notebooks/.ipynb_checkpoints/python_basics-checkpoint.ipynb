# %%
name = "Divine"
age = 20
is_student = True

print(f"Name: {name}, Age: {age}, Student: {is_student}")
# Lists and loops
courses = ["Intro to AI", "Data Structures", "Databases"]
for course in courses:
    print(f"Course: {course}")
# Functions
def calculate_average(scores):
    return sum(scores) / len(scores)

scores = [85, 92, 78, 95, 88]
print(f"Average score: {calculate_average(scores):.2f}")
# Out:
# Name: Divine, Age: 20, Student: True
# Course: Intro to AI
# Course: Data Structures
# Course: Databases
# Average score: 87.60
